# %% [markdown]
# <h1>Basic Custom Training Container</h1>

# %% [markdown]
# This notebook demonstrates how to build and use a basic custom Docker container for training with Amazon SageMaker. Reference documentation is available at https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-training-algo.html

# %% [markdown]
# We start by defining some variables like the current execution role, the ECR repository that we are going to use for pushing the custom Docker container and a default Amazon S3 bucket to be used by Amazon SageMaker.

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

ecr_namespace = 'aws_batch_tesseract/'
prefix = 'basic'

ecr_repository_name = ecr_namespace + prefix
role = get_execution_role()
account_id = role.split(':')[4]
region = boto3.Session().region_name
sagemaker_session = sagemaker.session.Session()
bucket = sagemaker_session.default_bucket()

print(account_id)
print(region)
print(role)
print(bucket)
# Out:
# 348831852500
# us-east-1
# arn:aws:iam::348831852500:role/service-role/AmazonSageMaker-ExecutionRole-20180906T165759
# sagemaker-us-east-1-348831852500

# %% [markdown]
# Let's take a look at the Dockerfile which defines the statements for building our custom SageMaker training container:

# %%
! pygmentize ./TESSERACT-SAGEMAKER-CONTAINER/Dockerfile
# Out:
# FROM ubuntu:18.04
#
# #
# # Defining some variables used at build time to install Python3
# ARG PYTHON=python3
# ARG PYTHON_PIP=python3-pip
# ARG PIP=pip3
# ARG PYTHON_VERSION=3.6.6
#
# #Non Interactive front end to avoid docker build stucks
# ENV DEBIAN_FRONTEND noninteractive
# ENV DEBIAN_FRONTEND teletype
# #Install Basic Packages
# #Install tesseract
# RUN echo ttf-mscorefonts-installer msttcorefonts/accepted-mscorefonts-eula select true |  debconf-set-selections
#
# RUN apt-get update && apt-get install -y --no-install-recommends software-properties-common && \
#     add-apt-repository ppa:deadsnakes/ppa -y && \
#     apt-get update && apt-get install -y --no-install-recommends \
#         build-essential \
#         ca-certificates \
#         curl \
#         wget \
#         git \
#         nginx \
#         openssh-client \
#         openssh-server \
#         zlib1g-dev \
#         unzip \
#         tesseract-ocr \
#         tesseract-ocr-ita \
#         ttf-mscorefonts-installer \
#         fonts-dejavu \
#         pdfsandwich && \
#     rm -rf /var/lib/apt/lists/*
#
# #Install Python
# RUN wget https://www.python.org/ftp/python/$PYTHON_VERSION/Python-$PYTHON_VERSION.tgz && \
#         tar -xvf Python-$PYTHON_VERSION.tgz && cd Python-$PYTHON_VERSION && \
#         ./configure && make && make install && \
#         apt-get update && apt-get install -y --no-install-recommends libreadline-gplv2-dev libncursesw5-dev libssl-dev libsqlite3-dev libgdbm-dev libc6-dev libbz2-dev && \
#         make -j 16 && make install && rm -rf ../Python-$PYTHON_VERSION* && \
#         ln -s /usr/local/bin/pip3 /usr/bin/pip
#
# # Upgrading pip and creating symbolic link for python3
# RUN ${PIP} --no-cache-dir install --upgrade pip
# RUN ln -s $(which ${PYTHON}) /usr/local/bin/python
#
# # Installing numpy, pandas, scikit-learn, scipy
# RUN ${PIP} install --no-cache --upgrade \
#         numpy==1.14.5 \
#         pandas==0.24.1 \
#         scikit-learn==0.20.3 \
#         requests==2.21.0 \
#         scipy==1.2.1
#
# # Here we install the extra python packages to run the inference code
# RUN pip install flask gevent gunicorn && \
#         rm -rf /root/.cache
#
# #Update font cache
# RUN fc-cache -vf
#
# # Setting some environment variables.
# ENV PYTHONDONTWRITEBYTECODE=1 \
#     PYTHONUNBUFFERED=1 \
#     LD_LIBRARY_PATH="${LD_LIBRARY_PATH}:/usr/local/lib" \
#     PYTHONIOENCODING=UTF-8 \
#     LANG=C.UTF-8 \
#     LC_ALL=C.UTF-8
#
# # Install Sagemaker integration scripts
# #RUN ${PIP} install --no-cache --upgrade \
# #    sagemaker-containers
#
# #Install AWS CLI
# RUN  curl "https://d1vvhvl2y92vvt.cloudfront.net/awscli-exe-linux-x86_64.zip" -o "awscliv2.zip"
# RUN unzip awscliv2.zip
# RUN ./aws/install
#
# COPY code/policy.xml /etc/ImageMagick-6/policy.xml
# COPY code/* /opt/ml/code/
# COPY tesseract-model /opt/ml/input_model/
# COPY langdata/ /opt/ml/langdata/
#
# RUN chmod 755 /opt/ml/code/*
#
# WORKDIR /opt/ml/code/
# ENV PATH=${PATH}:/opt/ml/code/
#
# #ENTRYPOINT ["/usr/local/bin/python", "/opt/ml/code/main.py"]
# #ENV SAGEMAKER_PROGRAM main.py

# %% [markdown]
# At high-level the Dockerfile specifies the following operations for building this container:
# <ul>
#     <li>Start from Ubuntu 18.04</li>
#     <li>Define some variables to be used at build time to install Python 3</li>
#     <li>Some handful libraries are installed with apt-get</li>
#     <li>tesseract and pdfsandwitch related libraries including fonts used for training</li>
#     <li>We then install Python 3 and create a symbolic link</li>
#     <li>We install some Python libraries like numpy, pandas, ScikitLearn, etc.</li>
#     <li>We set e few environment variables, including PYTHONUNBUFFERED which is used to avoid buffering Python standard output (useful for logging)</li>
#     <li>Finally, we copy all contents in <strong>code/</strong> (which is where our training code is) to the WORKDIR </li>
# </ul>

# %% [markdown]
# <h3>Build and push the container</h3>
# We are now ready to build this container and push it to Amazon ECR. This task is executed using a shell script stored in the ../script/ folder. Let's take a look at this script and then execute it.

# %%
! pygmentize ./scripts/build_and_push.sh
# Out:
# Error: cannot read infile: [Errno 2] No such file or directory: './scripts/build_and_push.sh'

# %% [markdown]
# <h3>--------------------------------------------------------------------------------------------------------------------</h3>
#
# The script builds the Docker container, then creates the repository if it does not exist, and finally pushes the container to the ECR repository. The build task requires a few minutes to be executed the first time, then Docker caches build outputs to be reused for the subsequent build operations.

# %%
# %%capture
! ./scripts/build_and_push.sh $account_id $region $ecr_repository_name

# %% [markdown]
# <h3>Training with Amazon SageMaker</h3>
#
# Once we have correctly pushed our container to Amazon ECR, we are ready to start training with Amazon SageMaker, which requires the ECR path to the Docker container used for training as parameter for starting a training job.

# %%
container_image_uri = '{0}.dkr.ecr.{1}.amazonaws.com/{2}:latest'.format(account_id, region, ecr_repository_name)
print(container_image_uri)
# Out:
# 348831852500.dkr.ecr.us-east-1.amazonaws.com/aws_batch_tesseract/basic:latest

# %% [markdown]
# Given the purpose of this example is explaining how to build custom containers, we are not going to train a real model. The script that will be executed does not define a specific training logic; it just outputs the configurations injected by SageMaker and implements a dummy training loop. Training data is also dummy. Let's analyze the code first:

# %%
! cat ./code/main.py
# Out:
# import os
# import sys
#
# print ("Starting Processing")
# print ("Arguments")
# print (sys.argv[0:])
#
# print ("Environment")
# print(os.environ)
# print ("End Environment")
#
# if 'SAGEMAKER_BATCH' in os.environ:
#     if (os.environ['SAGEMAKER_BATCH'].lower()=='true'):
#         print ("Start Image Processing")
#         os.system('/usr/bin/find /opt/ml')
#
# else:
#     print ("Start Training")
#     os.system('/bin/bash sagemaker_train_tesseract.sh')
#     print ("Training Complete")
#
# print ("End Processing training")

# %% [markdown]
# Finally, we can execute the training job by calling the fit() method of the generic Estimator object defined in the Amazon SageMaker Python SDK (https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/estimator.py). This corresponds to calling the CreateTrainingJob() API (https://docs.aws.amazon.com/sagemaker/latest/dg/API_CreateTrainingJob.html).

# %%
import sagemaker

est = sagemaker.estimator.Estimator(container_image_uri,
                                    role, 
                                    train_instance_count=1, 
                                    #train_instance_type='local', # use local mode
                                    train_instance_type='ml.c5.2xlarge',
                                    base_job_name=prefix
                                    )

est.set_hyperparameters(epoch=2000)

train_data = sagemaker.session.s3_input('s3://348831852500-sagemaker-us-east-1/Tesseract/training/')

est.fit({'train': train_data })
# Out:
# 2020-01-24 22:34:32 Starting - Starting the training job...
# 2020-01-24 22:34:34 Starting - Launching requested ML instances......
# 2020-01-24 22:35:42 Starting - Preparing the instances for training...
# 2020-01-24 22:36:28 Downloading - Downloading input data...
# 2020-01-24 22:36:44 Training - Downloading the training image...
# 2020-01-24 22:37:25 Training - Training image download completed. Training in progress.Training Params
# {'epoch': '2000'}
# Input Params
# {'train': {'TrainingInputMode': 'File', 'S3DistributionType': 'FullyReplicated', 'RecordWrapperType': 'None'}}
# Start Training
# Addind training file ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box
# Addind training file ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.tif
# Addind training file ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box
# Addind training file ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.tif
#
# ***** Prepare Training Data.
#
#
# === Copy existing box/tiff pairs from '/opt/ml/langdata/ita_box'
# total 17252
# -rw-r--r-- 1 root root  153837 Jan 24 22:37 ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box
# -rw-r--r-- 1 root root 8690656 Jan 24 22:37 ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.tif
# -rw-r--r-- 1 root root  107866 Jan 24 22:37 ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box
# -rw-r--r-- 1 root root 8701178 Jan 24 22:37 ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.tif
# -rw-r--r-- 1 root root       0 Jan 24 22:37 pippo.box
# -rw-r--r-- 1 root root       0 Jan 24 22:37 pippo.tif
# -rw-r--r-- 1 root root      66 Jan 24 22:37 tesstrain.log
#
# === Starting training for language 'ita'
# [Fri Jan 24 22:37:25 UTC 2020] /usr/bin/text2image --fonts_dir=/usr/share/fonts --font=Arial Bold --outputbase=/tmp/font_tmp.PHJ58OCAdM/sample_text.txt --text=/tmp/font_tmp.PHJ58OCAdM/sample_text.txt --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM
# Rendered page 0 to file /tmp/font_tmp.PHJ58OCAdM/sample_text.txt.tif
#
# === Phase I: Generating training images ===
# Rendering using Arial Bold
# [Fri Jan 24 22:37:27 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0 --max_pages=0 --font=Arial Bold --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.tif
# Rendering using Arial Bold Italic
# [Fri Jan 24 22:37:28 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0 --max_pages=0 --font=Arial Bold Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.tif
# Rendering using Arial Italic
# [Fri Jan 24 22:37:29 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0 --max_pages=0 --font=Arial Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.tif
# Rendering using Arial
# [Fri Jan 24 22:37:30 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Arial.exp0 --max_pages=0 --font=Arial --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.tif
# Rendering using Courier New Bold
# [Fri Jan 24 22:37:31 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0 --max_pages=0 --font=Courier New Bold --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.tif
# Rendering using Courier New Bold Italic
# [Fri Jan 24 22:37:32 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0 --max_pages=0 --font=Courier New Bold Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.tif
# Rendering using Courier New Italic
# [Fri Jan 24 22:37:33 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0 --max_pages=0 --font=Courier New Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.tif
# Rendering using Courier New
# [Fri Jan 24 22:37:34 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0 --max_pages=0 --font=Courier New --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.tif
# Rendering using Times New Roman, Bold
# [Fri Jan 24 22:37:35 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0 --max_pages=0 --font=Times New Roman, Bold --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.tif
# Rendering using Times New Roman, Bold Italic
# [Fri Jan 24 22:37:36 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0 --max_pages=0 --font=Times New Roman, Bold Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.tif
# Rendering using Times New Roman, Italic
# [Fri Jan 24 22:37:37 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0 --max_pages=0 --font=Times New Roman, Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.tif
# Rendering using Times New Roman,
# [Fri Jan 24 22:37:38 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0 --max_pages=0 --font=Times New Roman, --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.tif
# Rendering using Georgia Bold
# [Fri Jan 24 22:37:39 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0 --max_pages=0 --font=Georgia Bold --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.tif
# Rendering using Georgia Italic
# [Fri Jan 24 22:37:40 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0 --max_pages=0 --font=Georgia Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.tif
# Rendering using Georgia
# [Fri Jan 24 22:37:41 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Georgia.exp0 --max_pages=0 --font=Georgia --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.tif
# Rendering using Georgia Bold Italic
# [Fri Jan 24 22:37:42 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0 --max_pages=0 --font=Georgia Bold Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.tif
# Rendering using Trebuchet MS Bold
# [Fri Jan 24 22:37:43 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0 --max_pages=0 --font=Trebuchet MS Bold --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.tif
# Rendering using Trebuchet MS Bold Italic
# [Fri Jan 24 22:37:44 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0 --max_pages=0 --font=Trebuchet MS Bold Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.tif
# Rendering using Trebuchet MS Italic
# [Fri Jan 24 22:37:45 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0 --max_pages=0 --font=Trebuchet MS Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.tif
# Rendering using Trebuchet MS
# [Fri Jan 24 22:37:46 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0 --max_pages=0 --font=Trebuchet MS --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.tif
# Rendering using Verdana Bold
# [Fri Jan 24 22:37:47 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0 --max_pages=0 --font=Verdana Bold --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.tif
# Rendering using Verdana Italic
# [Fri Jan 24 22:37:48 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0 --max_pages=0 --font=Verdana Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.tif
# Rendering using Verdana
# [Fri Jan 24 22:37:49 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Verdana.exp0 --max_pages=0 --font=Verdana --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.tif
# Rendering using Verdana Bold Italic
# [Fri Jan 24 22:37:50 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0 --max_pages=0 --font=Verdana Bold Italic --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.tif
# Rendering using DejaVu Sans Ultra-Light
# [Fri Jan 24 22:37:51 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.PHJ58OCAdM --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0 --max_pages=0 --font=DejaVu Sans Ultra-Light --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.tif
# Rendered page 0 to file /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.tif
# Rendered page 1 to file /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.tif
#
# === Phase UP: Generating unicharset and unichar properties files ===
# [Fri Jan 24 22:37:52 UTC 2020] /usr/bin/unicharset_extractor --output_unicharset /tmp/ita-2020-01-24.RnU/ita.unicharset --norm_mode 1 /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.box /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.box /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.box /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.box /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.box /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.box /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.box /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box /tmp/ita-2020-01-24.RnU/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.box /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.box /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.box /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.box /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.box /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.box /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.box /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.box /tmp/ita-2020-01-24.RnU/pippo.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.box
# Failed to read data from: /tmp/ita-2020-01-24.RnU/pippo.box
# Wrote unicharset file /tmp/ita-2020-01-24.RnU/ita.unicharset
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/set_unicharset_properties -U /tmp/ita-2020-01-24.RnU/ita.unicharset -O /tmp/ita-2020-01-24.RnU/ita.unicharset -X /tmp/ita-2020-01-24.RnU/ita.xheights --script_dir=/opt/ml/langdata
# Loaded unicharset of size 122 from file /tmp/ita-2020-01-24.RnU/ita.unicharset
# Setting unichar properties
# Setting script properties
# Writing unicharset to file /tmp/ita-2020-01-24.RnU/ita.unicharset
#
# === Phase E: Generating lstmf files ===
# Using TESSDATA_PREFIX=/opt/ml/model/tessdata
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Arial.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:53 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 1
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 1
# Page 2
# Page 2
# Page 2
# Page 2
# Page 2
# Page 2
# Page 2
# Page 2
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.lstmf
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.lstmf
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.lstmf
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.lstmf
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.tif /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.lstmf
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# [Fri Jan 24 22:37:54 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# Page 2
# Page 2
# No block overlapping textline:
# Page 2
# Page 2
# Page 2
# [Fri Jan 24 22:37:55 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Page 2
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# No block overlapping textline:
# No block overlapping textline:
# [Fri Jan 24 22:37:55 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Loaded 50/50 pages (1-50) of document /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.lstmf
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.lstmf
# [Fri Jan 24 22:37:56 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:56 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:56 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.lstmf
# [Fri Jan 24 22:37:56 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:37:56 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# [Fri Jan 24 22:37:56 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 1
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 2
# Page 2
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.lstmf
# Page 2
# Page 2
# Page 2
# [Fri Jan 24 22:37:57 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Page 2
# Page 2
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.lstmf
# Page 2
# [Fri Jan 24 22:37:57 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Loaded 52/52 pages (1-52) of document /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.lstmf
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.lstmf
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.lstmf
# [Fri Jan 24 22:37:57 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.tif /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.lstmf
# Loaded 51/51 pages (1-51) of document /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.lstmf
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Loaded 49/49 pages (1-49) of document /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.lstmf
# Page 2
# Page 2
# Page 2
# Loaded 49/49 pages (1-49) of document /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.lstmf
# Loaded 49/49 pages (1-49) of document /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.lstmf
# Loaded 49/49 pages (1-49) of document /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.lstmf
# === Constructing LSTM training data ===
# [Fri Jan 24 22:37:59 UTC 2020] /usr/bin/combine_lang_model --input_unicharset /tmp/ita-2020-01-24.RnU/ita.unicharset --script_dir /opt/ml/langdata --words /opt/ml/langdata/ita/ita.wordlist --numbers /opt/ml/langdata/ita/ita.numbers --puncs /opt/ml/langdata/ita/ita.punc --output_dir ../tesstutorial/itatrain --lang ita
# Loaded unicharset of size 122 from file /tmp/ita-2020-01-24.RnU/ita.unicharset
# Setting unichar properties
# Setting script properties
# Config file is optional, continuing...
# Null char=2
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
#
# === Moving lstmf files for training data ===
# Moving /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Georgia_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.lstmf to ../tesstutorial/itatrain
# Moving /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.lstmf to ../tesstutorial/itatrain
#
# Created starter traineddata for LSTM training of language 'ita'
#
#
# Run 'lstmtraining' command to continue LSTM training for language 'ita'
#
#
# ***** Making evaluation data for itaeval set for scratch and impact training using Impact font.
#
# === Copy existing box/tiff pairs from '/opt/ml/langdata/ita_box'
# total 17252
# -rw-r--r-- 1 root root  153837 Jan 24 22:38 ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box
# -rw-r--r-- 1 root root 8690656 Jan 24 22:38 ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.tif
# -rw-r--r-- 1 root root  107866 Jan 24 22:38 ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box
# -rw-r--r-- 1 root root 8701178 Jan 24 22:38 ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.tif
# -rw-r--r-- 1 root root       0 Jan 24 22:38 pippo.box
# -rw-r--r-- 1 root root       0 Jan 24 22:38 pippo.tif
# -rw-r--r-- 1 root root      66 Jan 24 22:38 tesstrain.log
#
# === Starting training for language 'ita'
# [Fri Jan 24 22:38:04 UTC 2020] /usr/bin/text2image --fonts_dir=/usr/share/fonts --font=Impact Condensed --outputbase=/tmp/font_tmp.0008pqtbGx/sample_text.txt --text=/tmp/font_tmp.0008pqtbGx/sample_text.txt --fontconfig_tmpdir=/tmp/font_tmp.0008pqtbGx
# Rendered page 0 to file /tmp/font_tmp.0008pqtbGx/sample_text.txt.tif
#
# === Phase I: Generating training images ===
# Rendering using Impact Condensed
# [Fri Jan 24 22:38:06 UTC 2020] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.0008pqtbGx --fonts_dir=/usr/share/fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0 --max_pages=0 --font=Impact Condensed --text=/opt/ml/langdata/ita/ita.training_text
# Rendered page 0 to file /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.tif
# Rendered page 1 to file /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.tif
#
# === Phase UP: Generating unicharset and unichar properties files ===
# [Fri Jan 24 22:38:07 UTC 2020] /usr/bin/unicharset_extractor --output_unicharset /tmp/ita-2020-01-24.1hC/ita.unicharset --norm_mode 1 /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.box /tmp/ita-2020-01-24.1hC/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box /tmp/ita-2020-01-24.1hC/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box /tmp/ita-2020-01-24.1hC/pippo.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.1hC/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.box
# Extracting unicharset from box file /tmp/ita-2020-01-24.1hC/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.box
# Failed to read data from: /tmp/ita-2020-01-24.1hC/pippo.box
# Wrote unicharset file /tmp/ita-2020-01-24.1hC/ita.unicharset
# [Fri Jan 24 22:38:07 UTC 2020] /usr/bin/set_unicharset_properties -U /tmp/ita-2020-01-24.1hC/ita.unicharset -O /tmp/ita-2020-01-24.1hC/ita.unicharset -X /tmp/ita-2020-01-24.1hC/ita.xheights --script_dir=/opt/ml/langdata
# Loaded unicharset of size 122 from file /tmp/ita-2020-01-24.1hC/ita.unicharset
# Setting unichar properties
# Setting script properties
# Writing unicharset to file /tmp/ita-2020-01-24.1hC/ita.unicharset
#
# === Phase E: Generating lstmf files ===
# Using TESSDATA_PREFIX=/opt/ml/model/tessdata
# [Fri Jan 24 22:38:07 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.tif /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:38:07 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.1hC/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.tif /tmp/ita-2020-01-24.1hC/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# [Fri Jan 24 22:38:07 UTC 2020] /usr/bin/tesseract -l ita /tmp/ita-2020-01-24.1hC/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.tif /tmp/ita-2020-01-24.1hC/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0 lstm.train /opt/ml/langdata/ita/ita.config
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 1
# Page 1
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# Page 2
# No block overlapping textline:
# No block overlapping textline:
# No block overlapping textline:
# Loaded 49/49 pages (1-49) of document /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.lstmf
#
# === Constructing LSTM training data ===
# [Fri Jan 24 22:38:08 UTC 2020] /usr/bin/combine_lang_model --input_unicharset /tmp/ita-2020-01-24.1hC/ita.unicharset --script_dir /opt/ml/langdata --words /opt/ml/langdata/ita/ita.wordlist --numbers /opt/ml/langdata/ita/ita.numbers --puncs /opt/ml/langdata/ita/ita.punc --output_dir ../tesstutorial/itaeval --lang ita
# Loaded unicharset of size 122 from file /tmp/ita-2020-01-24.1hC/ita.unicharset
# Setting unichar properties
# Setting script properties
# Config file is optional, continuing...
# Null char=2
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
#
# === Moving lstmf files for training data ===
# Moving /tmp/ita-2020-01-24.1hC/ita.Impact_Condensed.exp0.lstmf to ../tesstutorial/itaeval
# Moving /tmp/ita-2020-01-24.1hC/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.lstmf to ../tesstutorial/itaeval
# Moving /tmp/ita-2020-01-24.1hC/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.lstmf to ../tesstutorial/itaeval
#
# Created starter traineddata for LSTM training of language 'ita'
#
#
# Run 'lstmtraining' command to continue LSTM training for language 'ita'
#
#
# ***** Extract LSTM model from best traineddata.
#
# Version string:4.00.00alpha:ita_old:synth20170629
# 17:lstm:size=7529667, offset=192
# 18:lstm-punc-dawg:size=4322, offset=7529859
# 19:lstm-word-dawg:size=2308154, offset=7534181
# 20:lstm-number-dawg:size=1946, offset=9842335
# 21:lstm-unicharset:size=6777, offset=9844281
# 22:lstm-recoder:size=1075, offset=9851058
# 23:version:size=34, offset=9852133
# Extracting tessdata components from /opt/ml/model/tessdata/best/ita.traineddata
# Wrote /opt/ml/model/impact_from_full/ita.lstm
#
# ***** Run lstmtraining with debug output for first 100 iterations.
#
# Loaded file /opt/ml/model/impact_from_full/ita.lstm, unpacking...
# Warning: LSTMTrainer deserialized an LSTMRecognizer!
# Continuing from /opt/ml/model/impact_from_full/ita.lstm
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Arial.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Arial_Bold.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Courier_New.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Courier_New_Bold.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Arial_Bold_Italic.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Arial_Italic.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.DejaVu_Sans_Ultra-Light.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Courier_New_Italic.exp0.lstmf
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Courier_New_Bold_Italic.exp0.lstmf
# Iteration 0: ALIGNED TRUTH : Privacy né una si La Roma, grande 2007, FÒ @*nome*@ Servizi un PG IN Messaggi: (6) Forum ...
# Iteration 0: BEST OCR TEXT : Privacy né una sì La Roma, grande 2007, FO @*nome*@ Servizi un PG IN Messaggi: (6) Forum ...
# File /tmp/ita-2020-01-24.RnU/ita.Arial.exp0.lstmf page 44 :
# Mean rms=1.038%, delta=1.927%, train=4.348%(11.111%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Georgia.exp0.lstmf
# Iteration 1: ALIGNED TRUTH : vBulletin® Cerca PER presso tutti, po' se - sempre 18 diritti gruppo per giorno film E' senza
# Iteration 1: BEST OCR TEXT : vBulletin® Cerca PER presso tutti, po' se - Sempre 18 diritti gruppo per giorno film E' senza
# File /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.lstmf page 17 :
# Mean rms=0.927%, delta=1.495%, train=3.249%(8.497%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Georgia_Bold.exp0.lstmf
# Iteration 2: ALIGNED TRUTH : Archivio ora 31 la sicurezza (7) le di puoi { produzione « DEGLI sono non ore però, Via tutte
# Iteration 2: BEST OCR TEXT : Archivio ora 31 la sicurezza (7) le di puoi { produzione « DEGLI sono non ore però, Via tutte
# File ../tesstutorial/itatrain/ita.Arial_Bold_Italic.exp0.lstmf page 0 (Perfect):
# Mean rms=0.67%, delta=0.997%, train=2.166%(5.664%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Georgia_Bold_Italic.exp0.lstmf
# Iteration 3: ALIGNED TRUTH : vBulletin® Cerca PER presso tutti, po' se - sempre 18 diritti gruppo per giorno film E' senza
# Iteration 3: BEST OCR TEXT : vBulletin® Cerca PER presso lutti, po' se - sempre 18 diritti gruppo per giorno film E' senza
# File /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.lstmf page 20 :
# Mean rms=0.667%, delta=0.939%, train=2.162%(5.719%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Georgia_Italic.exp0.lstmf
# Iteration 4: ALIGNED TRUTH : vBulletin® Cerca PER presso tutti, po' se - sempre 18 diritti gruppo per giorno film E' senza
# Iteration 4: BEST OCR TEXT : vBulletin® Cerca PER presso tutti, po' se - sempre 18 diritti gruppo per giorno film E' senza
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.lstmf page 14 (Perfect):
# Mean rms=0.555%, delta=0.751%, train=1.73%(4.575%), skip ratio=0%
# Loaded 115/115 pages (1-115) of document ../tesstutorial/itatrain/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.lstmf
# Iteration 5: ALIGNED TRUTH : pubblico tutte città sui dal ricerca 4 S. ;) INFORMAZIONI figlio due all'interno servizi and
# Iteration 5: BEST OCR TEXT : pubblico tutte città sui dal ricerca 4 s8S. ;) INFORMAZIONI figlio due all'interno servizi and
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold.exp0.lstmf page 49 :
# Mean rms=0.549%, delta=0.711%, train=1.804%(4.924%), skip ratio=0%
# Loaded 119/119 pages (1-119) of document ../tesstutorial/itatrain/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.lstmf
# Iteration 6: ALIGNED TRUTH : Link oltre anche Nokia informazioni Home una possibile privacy Servizi 1 Risposta questa che
# Iteration 6: BEST OCR TEXT : Link oltre anche Nokia informazioni Home una possibile privacy Servizi 1 Risposta questa che
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.lstmf page 20 (Perfect):
# Mean rms=0.487%, delta=0.61%, train=1.546%(4.22%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Times_New_Roman.exp0.lstmf
# Iteration 7: ALIGNED TRUTH : Fotografia] 18 --- 30 FORUM << Profilo <a Sport SRL giorni CIÒ commento della tuo 13 chi
# Iteration 7: BEST OCR TEXT : Fotografia] 18 - - 30 FORUM << Profilo <a Sport SRL giorni CIÒ commento della tuo 13 chi
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.lstmf page 22 :
# Mean rms=0.5%, delta=0.584%, train=1.637%(4.428%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Times_New_Roman_Bold.exp0.lstmf
# Iteration 8: ALIGNED TRUTH : Yahoo! Se viene 23 contenuti messaggio musica per ha MediaWiki delle - you utente? maggio
# Iteration 8: BEST OCR TEXT : Yahoo! Se viene 23 contenuti messaggio musica per ha MediaWiki delle - you utente? maggio
# File /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.lstmf page 7 (Perfect):
# Mean rms=0.463%, delta=0.519%, train=1.455%(3.936%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Times_New_Roman_Bold_Italic.exp0.lstmf
# Iteration 9: ALIGNED TRUTH : post . In sarà of tre Informazioni I profilo senza Per Torna 6 che Il ©2008 l' eBay eBay; (
# Iteration 9: BEST OCR TEXT : post . In sarà of tre Informazioni I profilo senza Per Torna 6 che Il ©2008 1' eBay eBay; (
# File ../tesstutorial/itatrain/ita.Georgia.exp0.lstmf page 0 :
# Mean rms=0.476%, delta=0.516%, train=1.529%(4.042%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Times_New_Roman_Italic.exp0.lstmf
# Iteration 10: ALIGNED TRUTH : NON 14 amico proprio 1. Blocca km ed SENZA > Blog bene tutto grazie miei e The the Top possono
# Iteration 10: BEST OCR TEXT : NON 14 amico proprio 1. Blocca km ed SENZA > Blog bene tutto grazie miei e The the Top possono
# File /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.lstmf page 26 (Perfect):
# Mean rms=0.443%, delta=0.469%, train=1.39%(3.675%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Trebuchet_MS.exp0.lstmf
# Iteration 11: ALIGNED TRUTH : Aggiungi verso mia DI Il in del offerte +39 modo Pagina sezione sul senza CHE suo messaggio 30
# Iteration 11: BEST OCR TEXT : Aggiungi verso mia DI Il in del offerte +39 modo Pagina sezione sul senza CHE suo messaggio 30
# File /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.lstmf page 2 (Perfect):
# Mean rms=0.428%, delta=0.43%, train=1.274%(3.369%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Trebuchet_MS_Bold.exp0.lstmf
# Iteration 12: ALIGNED TRUTH : fare ha Informazioni | video Forum 3 Navigazione, Tutti sito Aggiungi e stata ; sempre proprio
# Iteration 12: BEST OCR TEXT : fare ha Informazioni | video Forum 3 Navigazione, Tutti sìto Aggiungi e stata ; sempre proprio
# File ../tesstutorial/itatrain/ita.Georgia_Italic.exp0.lstmf page 0 :
# Mean rms=0.444%, delta=0.434%, train=1.34%(3.59%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Trebuchet_MS_Bold_Italic.exp0.lstmf
# Iteration 13: ALIGNED TRUTH : - 1319 -
# Iteration 13: BEST OCR TEXT : - 4319 -
# File ../tesstutorial/itatrain/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.lstmf page 0 :
# Mean rms=0.603%, delta=1.197%, train=3.03%(5.715%), skip ratio=0%
# Loaded 77/77 pages (1-77) of document ../tesstutorial/itatrain/ita.Trebuchet_MS_Italic.exp0.lstmf
# Iteration 14: ALIGNED TRUTH : feriti, mutilati e decorati, 21179 - tra-
# Iteration 14: BEST OCR TEXT : feriti, mutilati e decorati, 21179 - tra-
# File ../tesstutorial/itatrain/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.lstmf page 0 (Perfect):
# Mean rms=0.575%, delta=1.117%, train=2.828%(5.334%), skip ratio=0%
# ...
# File ../tesstutorial/itatrain/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.lstmf page 2 :
# Mean rms=0.52%, delta=1.023%, train=3.079%(5.944%), skip ratio=11.29%
# Iteration 62: ALIGNED TRUTH : giorni, di film via Iscritto InfoJobs anche corso di cui Firenze luglio dal P_MSG la nome HD
# Iteration 62: BEST OCR TEXT : giorni, di film via Iscritto InfoJobs anche corso di cui Firenze luglio dal P_MSG la nome HD
# File /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman.exp0.lstmf page 2 (Perfect):
# Mean rms=0.513%, delta=1.007%, train=3.031%(5.849%), skip ratio=11.111%
# Iteration 63: ALIGNED TRUTH : sito di Valutazione: chi giorni cui come Hotel €. text: essere non film AM Annunci città
# Iteration 63: BEST OCR TEXT : sito di Valutazione: chi giorni cui come Hotel €. text: essere non film AM Annunci città
# File /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.lstmf page 44 (Perfect):
# Mean rms=0.507%, delta=0.991%, train=2.983%(5.758%), skip ratio=10.938%
# Iteration 64: ALIGNED TRUTH : CONDÉNET senza Aggiungi Web video contatti ancora subito ESSERE (1) ad ©2000 poco si [IMG]
# Iteration 64: BEST OCR TEXT : CONDENET senza Aggiungi Web video contatti ancora subito ESSERE (1) ad ©2000 poco sì [IMG]
# File ../tesstutorial/itatrain/ita.Times_New_Roman_Bold_Italic.exp0.lstmf page 2 :
# Mean rms=0.515%, delta=1.001%, train=3.006%(5.875%), skip ratio=10.769%
# Iteration 65: ALIGNED TRUTH : Messaggi: 24 parte altri prodotto su a più più un Milano, e mondo on tra LA / PC siamo in
# Iteration 65: BEST OCR TEXT : Messaggi: 24 parte altri prodotto su a più più un Milano, e mondo on tra LA / PC siamo in
# File /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.lstmf page 45 (Perfect):
# Mean rms=0.509%, delta=0.985%, train=2.96%(5.786%), skip ratio=10.606%
# Iteration 66: ALIGNED TRUTH : ARCHIVIO hanno Kijiji EUR annunci Chi con Web sistema nuovo mi dal: informazioni sulla
# Iteration 66: BEST OCR TEXT : ARCHIVIO hanno Kijiji EUR annunci Chi con Web sistema nuovo mi dal: informazioni sulla
# File /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.lstmf page 13 (Perfect):
# Mean rms=0.503%, delta=0.971%, train=2.916%(5.699%), skip ratio=10.448%
# Encoding of string failed! Failure bytes: 24 20 69 6f 20 ffffffc2 ffffffa9 20 63 6f 73 ffffffc3 ffffffac 20 64 69 63 65 6d 62 72 65 20 71 75 65 73 74 61 20 7d 7d 20 22 ffffffc3 ffffff88 20 43 6f 70 79 72 69 67 68 74 20 5c 20 73 6f 6e 6f 20 ffffffc3 ffffffa8 20 53 45 52 56 49 5a 49 20 65 73 73 65 72 65
# Can't encode transcription: 'Art. è giorni per 75$ io © così dicembre questa }} "È Copyright \ sono è SERVIZI essere' in language ''
# Iteration 67: ALIGNED TRUTH : pubblico tutte città sui dal ricerca 4 S. ;) INFORMAZIONI figlio due all'interno servizi and
# Iteration 67: BEST OCR TEXT : pubblico tutte città sui dal ricerca 4 S. ;) INFORMAZIONI figlio due all'interno servizi and
# File /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.lstmf page 42 (Perfect):
# Mean rms=0.5%, delta=0.956%, train=2.873%(5.615%), skip ratio=11.765%
# Iteration 68: ALIGNED TRUTH : messaggi lavoro, 16 PDF il 24/10/2008 mentre e e HKLM\..\Run: di Servizi può su vita uno che
# Iteration 68: BEST OCR TEXT : messaggi lavoro, 16 PDF il 24/ 10/2008 mentre e e HKLM\..\Run: di Servizi può su vita uno che
# File ../tesstutorial/itatrain/ita.Trebuchet_MS_Italic.exp0.lstmf page 2 (Perfect):
# Mean rms=0.498%, delta=0.943%, train=2.847%(5.619%), skip ratio=11.594%
# Iteration 69: ALIGNED TRUTH : fare ha Informazioni | video Forum 3 Navigazione, Tutti sito Aggiungi e stata ; sempre proprio
# Iteration 69: BEST OCR TEXT : fare ha Informazioni | video Forum 3 Navigazione, Tutti sìito Aggiungi e stata ; sempre proprio
# File ../tesstutorial/itatrain/ita.Verdana.exp0.lstmf page 2 :
# Mean rms=0.496%, delta=0.935%, train=2.822%(5.628%), skip ratio=11.429%
# Iteration 70: ALIGNED TRUTH : : '900 fu sarà Servizi hanno | e presso quella CITTÀ agli ancora questa - «È molto e B&B
# Iteration 70: BEST OCR TEXT : : '900 fu sarà Servizi hanno | e presso quella CITTÀ agli ancora questa - «È molto e B&B
# File /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold.exp0.lstmf page 4 (Perfect):
# Mean rms=0.492%, delta=0.922%, train=2.782%(5.549%), skip ratio=11.268%
# Iteration 71: ALIGNED TRUTH : NON 14 amico proprio 1. Blocca km ed SENZA > Blog bene tutto grazie miei e The the Top possono
# Iteration 71: BEST OCR TEXT : NON 14 amico proprio 1. Blocca km ed SENZA > Blog bene tutto grazie miei e The the Top possono
# File /tmp/ita-2020-01-24.RnU/ita.Verdana_Bold_Italic.exp0.lstmf page 48 (Perfect):
# Mean rms=0.487%, delta=0.91%, train=2.743%(5.472%), skip ratio=11.111%
# Iteration 72: ALIGNED TRUTH : modo con Visualizza particolare sono quello potrebbe FACT-Finder® => CD link siamo Venezia
# Iteration 72: BEST OCR TEXT : modo con Visualizza particolare sono quello potrebbe FACT-Finder® => CD link siamo Venezia
# File /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.lstmf page 24 (Perfect):
# Mean rms=0.482%, delta=0.897%, train=2.706%(5.397%), skip ratio=10.959%
# Iteration 73: ALIGNED TRUTH : fontsize:S 2° "Non ICQ at: ma come fatto dal del Da che prima GESÙ servizi sicurezza fu
# Iteration 73: BEST OCR TEXT : fontsize:S 2° "Non ICQ at: ma come fatto dal del Da che prima GESÙ servizi sicurezza fu
# File ../tesstutorial/itatrain/ita.Arial.exp0.lstmf page 3 (Perfect):
# Mean rms=0.478%, delta=0.885%, train=2.669%(5.324%), skip ratio=10.811%
# Iteration 74: ALIGNED TRUTH : Registrati cosa nella che e Ricerca sui RSS "{" di 2007 N. prezzo by 2. nelle attività | dello
# Iteration 74: BEST OCR TEXT : Registrati cosa nella che e Ricerca sui RSS "{" di 2007 N. prezzo by 2. nelle attività | dello
# File /tmp/ita-2020-01-24.RnU/ita.Arial_Bold.exp0.lstmf page 6 (Perfect):
# Mean rms=0.473%, delta=0.873%, train=2.634%(5.253%), skip ratio=10.667%
# Iteration 75: ALIGNED TRUTH : Milano dell'Île poi - -, perché seconda del dai notizie messaggi zona de marzo 2Î9 gli e
# Iteration 75: BEST OCR TEXT : Milano dell'Île poi - -, perché seconda del dai notizie messaggi zona de marzo 2Î9 gli e
# File /tmp/ita-2020-01-24.RnU/ita.Arial_Bold_Italic.exp0.lstmf page 26 (Perfect):
# Mean rms=0.469%, delta=0.862%, train=2.599%(5.184%), skip ratio=10.526%
# Iteration 76: ALIGNED TRUTH : ARCHIVIO hanno Kijiji EUR annunci Chi con Web sistema nuovo mi dal: informazioni sulla
# Iteration 76: BEST OCR TEXT : ARCHIVIO hanno Kijiji EUR annunci Chi con Web sistema nuovo mi dal: informazioni Sulla
# File /tmp/ita-2020-01-24.RnU/ita.Arial_Italic.exp0.lstmf page 10 :
# Mean rms=0.471%, delta=0.86%, train=2.595%(5.209%), skip ratio=10.39%
# Iteration 77: ALIGNED TRUTH : "Il «La la "Il vita dalle Forum Privacy al "È - Spedizione 19 (1) un dei Kurdî 2005
# Iteration 77: BEST OCR TEXT : "Il «La la "Il vita dalle Forum Privacy al "E - Spedizione 19 (1) un dei Kurdî 2005
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New.exp0.lstmf page 20 :
# Mean rms=0.476%, delta=0.859%, train=2.593%(5.214%), skip ratio=10.256%
# Iteration 78: ALIGNED TRUTH : questo al più, è già Risposta - ad commenti 8 Cerca fu accessori parte così secondo un'altra
# Iteration 78: BEST OCR TEXT : questo al più, è già Risposta - ad commenti 8 Cerca fu accessori parte così secondo un'altra
# File ../tesstutorial/itatrain/ita.Courier_New_Bold.exp0.lstmf page 3 (Perfect):
# Mean rms=0.471%, delta=0.849%, train=2.56%(5.148%), skip ratio=10.127%
# Iteration 79: ALIGNED TRUTH : ... commenti Ricerca di deve uno for 2004 primo molto 2008 per che " ex 9 in E in perché di
# Iteration 79: BEST OCR TEXT : «-. commenti Ricerca di deve uno for 2004 primo molto 2008 per che " ex 9 in E in perché di
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New_Bold_Italic.exp0.lstmf page 46 :
# Mean rms=0.473%, delta=0.848%, train=2.583%(5.143%), skip ratio=10%
# Iteration 80: ALIGNED TRUTH : NON 14 amico proprio 1. Blocca km ed SENZA > Blog bene tutto grazie miei e The the Top possono
# Iteration 80: BEST OCR TEXT : NON 14 amico proprio 1. Blocca km ed SENZA > Blog bene tutto grazie miei e The the Top possono
# File /tmp/ita-2020-01-24.RnU/ita.Courier_New_Italic.exp0.lstmf page 35 (Perfect):
# Mean rms=0.468%, delta=0.837%, train=2.551%(5.08%), skip ratio=9.877%
# Iteration 81: ALIGNED TRUTH : e - dicembre > fl caso le tuo anche dei e (€) IX presente novembre su fl così gli 2008,
# Iteration 81: BEST OCR TEXT : e - dicembre > fl caso le tuo anche dei e (€) |X presente novembre su fl così gli 2008,
# File /tmp/ita-2020-01-24.RnU/ita.DejaVu_Sans_Ultra-Light.exp0.lstmf page 27 :
# Mean rms=0.47%, delta=0.836%, train=2.548%(5.079%), skip ratio=9.756%
# Iteration 82: ALIGNED TRUTH : pubblico tutte città sui dal ricerca 4 S. ;) INFORMAZIONI figlio due all'interno servizi and
# Iteration 82: BEST OCR TEXT : pubblico tutte città sui dal ricerca 4 S. ;) INFORMAZIONI figlio due all'interno servizi and
# File /tmp/ita-2020-01-24.RnU/ita.Georgia.exp0.lstmf page 1 (Perfect):
# Mean rms=0.466%, delta=0.826%, train=2.517%(5.017%), skip ratio=9.639%
# Iteration 83: ALIGNED TRUTH : Registrati cosa nella che e Ricerca sui RSS "{" di 2007 N. prezzo by 2. nelle attività | dello
# Iteration 83: BEST OCR TEXT : Registrati cosa nella che e Ricerca sui RSS "{" di 2007 N. prezzo by 2. nelle attività | dello
# File /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold.exp0.lstmf page 1 (Perfect):
# Mean rms=0.462%, delta=0.816%, train=2.488%(4.958%), skip ratio=9.524%
# Iteration 84: ALIGNED TRUTH : : degli cui prodotti rispetto e tra Mappa 6 di due profilo qui un di 3. Notizie di con nostro -
# Iteration 84: BEST OCR TEXT : : degli cui prodotti rispetto e tra Mappa 6 di due profilo qui un di 3. Notizie di con nostro -
# File /tmp/ita-2020-01-24.RnU/ita.Georgia_Bold_Italic.exp0.lstmf page 7 (Perfect):
# Mean rms=0.459%, delta=0.807%, train=2.458%(4.899%), skip ratio=9.412%
# Iteration 85: ALIGNED TRUTH : vendita blog sulla »» fontsize:S uno i VENERDÌ Non il Messaggi: Libri x Archivio questo by
# Iteration 85: BEST OCR TEXT : vendita blog sulla »» fontsize:S uno i VENERDÌ Non il Messaggi: Libri x Archivio questo by
# File ../tesstutorial/itatrain/ita.Georgia_Italic.exp0.lstmf page 3 (Perfect):
# Mean rms=0.456%, delta=0.797%, train=2.43%(4.842%), skip ratio=9.302%
# Iteration 86: ALIGNED TRUTH : dozione delle famiglie dei militari morti o resi inabili al
# Iteration 86: BEST OCR TEXT : dozione delle famiglie dei militari morti o resì inabili al
# File ../tesstutorial/itatrain/ita.Leg_001_DA00_cat_002.pdf_page0000.exp0.lstmf page 3 :
# Mean rms=0.46%, delta=0.799%, train=2.441%(4.902%), skip ratio=9.195%
# Iteration 87: ALIGNED TRUTH : dell'Acquedotto pugliese, 7758 - emen-
# Iteration 87: BEST OCR TEXT : dell'Acquedotto pugliese, 7758 - emen-
# File ../tesstutorial/itatrain/ita.Leg_024_IR01_cat_022.pdf_page0001.exp0.lstmf page 3 (Perfect):
# Mean rms=0.456%, delta=0.79%, train=2.413%(4.846%), skip ratio=9.091%
# Iteration 88: ALIGNED TRUTH : riservati. ricerca delle
# Iteration 88: BEST OCR TEXT : riservati. ricerca delle
# File ../tesstutorial/itatrain/ita.Times_New_Roman.exp0.lstmf page 3 (Perfect):
# Mean rms=0.452%, delta=0.781%, train=2.386%(4.791%), skip ratio=8.989%
# Iteration 89: ALIGNED TRUTH : forum mia come Più anche RSS "La fontsize:S voce aprile altri Tel. = all'inizio | e per
# Iteration 89: BEST OCR TEXT : forum mia come Più anche RSS "La fontsize:S voce aprile altri Tel. = all'inizio | e per
# File /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold.exp0.lstmf page 3 (Perfect):
# Mean rms=0.448%, delta=0.772%, train=2.359%(4.738%), skip ratio=8.889%
# Iteration 90: ALIGNED TRUTH : (Îles gli - volta sono Privacy base un era di ;-) ma USA chi blog comune sul mondo questo " I
# Iteration 90: BEST OCR TEXT : (Îles gli - volta sono Privacy base un era di ;-) ma USA chi blog comune sul mondo questo "I
# File /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Bold_Italic.exp0.lstmf page 3 :
# Mean rms=0.449%, delta=0.769%, train=2.345%(4.791%), skip ratio=8.791%
# Iteration 91: ALIGNED TRUTH : Privacy né una si La Roma, grande 2007, FÒ @*nome*@ Servizi un PG IN Messaggi: (6) Forum ...
# Iteration 91: BEST OCR TEXT : Privacy né una si La Roma, grande 2007, FÒ @ *nome*@, Servizi un PG IN Messaggi: (6) Forum ...
# File /tmp/ita-2020-01-24.RnU/ita.Times_New_Roman_Italic.exp0.lstmf page 36 :
# Mean rms=0.453%, delta=0.774%, train=2.343%(4.799%), skip ratio=8.696%
# Iteration 92: ALIGNED TRUTH : codice ma dal numero 2 14 anche primo infatti, P_EMAIL Chi su senza dalla non i Sport
# Iteration 92: BEST OCR TEXT : codice ma dal numero 2 14 anche primo infatti, P_EMAIL Chi su senza dalla non i Sport
# File /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS.exp0.lstmf page 46 (Perfect):
# Mean rms=0.449%, delta=0.766%, train=2.318%(4.748%), skip ratio=8.602%
# Iteration 93: ALIGNED TRUTH : blog miei e ne » Errore, una di & 1 , un sulla che News MIELEPIÙ caso - una Home per ANCHE di
# Iteration 93: BEST OCR TEXT : blog miei e ne » Errore, una di & 1, un sulla che News MIELEPIÙ caso - una Home per ANCHE di
# File /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold.exp0.lstmf page 48 (Perfect):
# Mean rms=0.448%, delta=0.758%, train=2.305%(4.79%), skip ratio=8.511%
# Iteration 94: ALIGNED TRUTH : forum mia come Più anche RSS "La fontsize:S voce aprile altri Tel. = all'inizio | e per
# Iteration 94: BEST OCR TEXT : forum mia come Più anche RSS "La fontsize:S voce aprile altri Tel. = all'inizio | e per
# File /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Bold_Italic.exp0.lstmf page 8 (Perfect):
# Mean rms=0.445%, delta=0.75%, train=2.281%(4.739%), skip ratio=8.421%
# Iteration 95: ALIGNED TRUTH : Privacy né una si La Roma, grande 2007, FÒ @*nome*@ Servizi un PG IN Messaggi: (6) Forum ...
# Iteration 95: BEST OCR TEXT : Privacy né una sì La Roma, grande 2007, FÒ @*nome*@ Servizi un PG IN Messaggi: (6) Forum ...
# File /tmp/ita-2020-01-24.RnU/ita.Trebuchet_MS_Italic.exp0.lstmf page 15 :
# Mean rms=0.446%, delta=0.746%, train=2.28%(4.748%), skip ratio=8.333%
# Iteration 96: ALIGNED TRUTH : shift:(-10,5) ottobre Risposta ho ciò solo Tutti 1 invece, PER per Messaggi: poi € + E' in
# Iteration 96: BEST OCR TEXT : shift:(-10,5) ottobre Risposta ho ciò solo Tutti 1 invece, PER per Messaggi: poi € + E' in
# File /tmp/ita-2020-01-24.RnU/ita.Verdana.exp0.lstmf page 6 (Perfect):
# Mean rms=0.443%, delta=0.738%, train=2.256%(4.699%), skip ratio=8.247%
# Iteration 97: ALIGNED TRUTH : Copyright quanto nel 2009 PERCHÉ società anni, dove la come per è è La 2, Informazioni
# Iteration 97: BEST OCR TEXT : Copyright quanto nel 2009 PERCHÉ società anni, dove la come per è è La 2, Informazioni
# File ../tesstutorial/itatrain/ita.Verdana_Bold.exp0.lstmf page 3 (Perfect):
# Mean rms=0.439%, delta=0.731%, train=2.233%(4.651%), skip ratio=8.163%
# Iteration 98: ALIGNED TRUTH : FC 24 dalla e 7 3° tutto Wikipedia E prima Non grande abuso # fino utente vi marzo da 10 Il
# Iteration 98: BEST OCR TEXT : FC 24 dalla e 7 3° tutto Wikipedia E prima Non grande abuso # fino utente vi marzo da 10 Il
# File ../tesstutorial/itatrain/ita.Verdana_Bold_Italic.exp0.lstmf page 3 (Perfect):
# Mean rms=0.436%, delta=0.723%, train=2.21%(4.604%), skip ratio=8.081%
# Iteration 99: ALIGNED TRUTH : fino The anche ancora questo messaggio quando lavoro suo sempre tua 50% nella solo Video nel 50
# Iteration 99: BEST OCR TEXT : fino The anche ancora questo messaggio quando lavoro suo sempre tua 50% nella solo Video nel 50
# File /tmp/ita-2020-01-24.RnU/ita.Verdana_Italic.exp0.lstmf page 46 (Perfect):
# Mean rms=0.433%, delta=0.716%, train=2.188%(4.558%), skip ratio=8%
# 2 Percent improvement time=41, best error was 100 @ 0
# At iteration 41/100/108, Mean rms=0.433%, delta=0.716%, char train=2.188%, word train=4.558%, skip ratio=8%,  New best char error = 2.188 Transitioned to stage 1 wrote best model:/opt/ml/model/impact_from_full/impact2.188_41.checkpoint wrote checkpoint.
#
# Finished! Error rate = 2.188
#
# ***** Continue lstmtraining till 2000 iterations.
#
# ***** Run lstmeval on eval set.
#
# ***** Run lstmeval on itatrain set.
#
#
# 2020-01-24 23:00:23 Uploading - Uploading generated training model***** Stop lstmtraining and convert to traineddata.
#
# Loaded file /opt/ml/model/impact_from_full/impact_checkpoint, unpacking...
# Training Complete
#
# 2020-01-24 23:01:15 Completed - Training job completed
# Training seconds: 1487
# Billable seconds: 1487

# %%
! cat process.csv
#InputBucket,#InputPath,#InputFileName,#OutputBucket,#OutputPath,#OutputFileName,
# Out:
# 348831852500-sagemaker-us-east-1,Tesseract/Input,Leg_001_DA00_cat_002.pdf,348831852500-sagemaker-us-east-1,Tesseract/Output,OUT_Leg_001_DA00_cat_002.pdf
# 348831852500-sagemaker-us-east-1,Tesseract/Input,Leg_027_IR01_cat_025.pdf,348831852500-sagemaker-us-east-1,Tesseract/Output,OUT_Leg_027_IR01_cat_025.pdf

# %%
# !aws s3 cp process.csv s3://348831852500-sagemaker-us-east-1/Tesseract/process/process.csv
# Out:
# upload: ./process.csv to s3://348831852500-sagemaker-us-east-1/Tesseract/process/process.csv

# %%
batch_input = 's3://348831852500-sagemaker-us-east-1/Tesseract/process/process.csv'

# The location to store the results of the batch transform job
batch_output = 's3://348831852500-sagemaker-us-east-1/Tesseract/Output/'


batch=est.transformer (instance_count=1, 
                       instance_type='ml.c5.9xlarge', 
                       #instance_type='local', # use local mode
                       output_path=batch_output,
                       strategy ="SingleRecord",
                       max_concurrent_transforms=1)
# Out:
# Using already existing model: basic-2020-01-24-22-34-31-989

# %%
batch.transform(data=batch_input, data_type='S3Prefix',  content_type='text/csv', split_type='Line')

# %%
batch.wait()
# Out:
# ...................Starting the inference server with 1 workers.
# [2020-01-25 10:24:36 +0000] [11] [INFO] Starting gunicorn 20.0.4
# [2020-01-25 10:24:36 +0000] [11] [INFO] Listening at: unix:/tmp/gunicorn.sock (11)
# [2020-01-25 10:24:36 +0000] [11] [INFO] Using worker: gevent
# [2020-01-25 10:24:36 +0000] [15] [INFO] Booting worker with pid: 15
# Setup Model
# Starting the inference server with 1 workers.
# [2020-01-25 10:24:36 +0000] [11] [INFO] Starting gunicorn 20.0.4
# [2020-01-25 10:24:36 +0000] [11] [INFO] Listening at: unix:/tmp/gunicorn.sock (11)
# [2020-01-25 10:24:36 +0000] [11] [INFO] Using worker: gevent
# [2020-01-25 10:24:36 +0000] [15] [INFO] Booting worker with pid: 15
# Setup Model
# 169.254.255.130 - - [25/Jan/2020:10:24:39 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [25/Jan/2020:10:24:39 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Request
# text/csv
# Data
# Start Processing
# Input Bucket: 348831852500-sagemaker-us-east-1
# Input Path: Tesseract/Input
# Input File Name: Leg_001_DA00_cat_002.pdf
# Output Bucket:
# Output Path: Tesseract/Output
# Output File Name: OUT_Leg_001_DA00_cat_002.pdf
# ############################### DOWNLOAD INPUT FILE ###########################
# 169.254.255.130 - - [25/Jan/2020:10:24:39 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [25/Jan/2020:10:24:39 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Request
# text/csv
# Data
# Start Processing
# Input Bucket: 348831852500-sagemaker-us-east-1
# Input Path: Tesseract/Input
# Input File Name: Leg_001_DA00_cat_002.pdf
# Output Bucket:
# Output Path: Tesseract/Output
# Output File Name: OUT_Leg_001_DA00_cat_002.pdf
# ############################### DOWNLOAD INPUT FILE ###########################
# 2020-01-25T10:24:39.187:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=SINGLE_RECORD
# Completed 256.0 KiB/802.8 KiB (2.3 MiB/s) with 1 file(s) remaining#015Completed 512.0 KiB/802.8 KiB (4.3 MiB/s) with 1 file(s) remaining#015Completed 768.0 KiB/802.8 KiB (6.2 MiB/s) with 1 file(s) remaining#015Completed 802.8 KiB/802.8 KiB (6.4 MiB/s) with 1 file(s) remaining#015download: s3://348831852500-sagemaker-us-east-1/Tesseract/Input/Leg_001_DA00_cat_002.pdf to ./Leg_001_DA00_cat_002.pdf
# ############################### TESSERACT EXECUTION ###########################
# pdfsandwich version 0.1.7
# Input file: "Leg_001_DA00_cat_002.pdf"
# Completed 256.0 KiB/802.8 KiB (2.3 MiB/s) with 1 file(s) remaining#015Completed 512.0 KiB/802.8 KiB (4.3 MiB/s) with 1 file(s) remaining#015Completed 768.0 KiB/802.8 KiB (6.2 MiB/s) with 1 file(s) remaining#015Completed 802.8 KiB/802.8 KiB (6.4 MiB/s) with 1 file(s) remaining#015download: s3://348831852500-sagemaker-us-east-1/Tesseract/Input/Leg_001_DA00_cat_002.pdf to ./Leg_001_DA00_cat_002.pdf
# ############################### TESSERACT EXECUTION ###########################
# pdfsandwich version 0.1.7
# Input file: "Leg_001_DA00_cat_002.pdf"
# Output file: "Leg_001_DA00_cat_002_ocr.pdf"
# Number of pages in inputfile: 2
# Output file: "Leg_001_DA00_cat_002_ocr.pdf"
# Number of pages in inputfile: 2
# More threads than pages. Using 2 threads instead.
#
# Parallel processing with 2 threads started.
# Processing page order may differ from original page order.
#
# Processing page 2.
# Processing page 1.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmpf582f5/pdfsandwich_inputfileb8428e.pdf[1]"
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmpf582f5/pdfsandwich_inputfileb8428e.pdf[0]"
# More threads than pages. Using 2 threads instead.
#
# Parallel processing with 2 threads started.
# Processing page order may differ from original page order.
#
# Processing page 2.
# Processing page 1.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmpf582f5/pdfsandwich_inputfileb8428e.pdf[1]"
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmpf582f5/pdfsandwich_inputfileb8428e.pdf[0]"
# Done.
# ############################ PACKAGE OUTPUT AND UPLOAD ########################
# Done.
# ############################ PACKAGE OUTPUT AND UPLOAD ########################
# Completed 256.0 KiB/271.8 KiB (3.0 MiB/s) with 1 file(s) remaining#015Completed 271.8 KiB/271.8 KiB (1.2 MiB/s) with 1 file(s) remaining#015upload: ./Leg_001_DA00_cat_002_ocr.pdf to s3://348831852500-sagemaker-us-east-1/Tesseract/Output/OUT_Leg_001_DA00_cat_002.pdf
# Completed 256.0 KiB/271.8 KiB (3.0 MiB/s) with 1 file(s) remaining#015Completed 271.8 KiB/271.8 KiB (1.2 MiB/s) with 1 file(s) remaining#015upload: ./Leg_001_DA00_cat_002_ocr.pdf to s3://348831852500-sagemaker-us-east-1/Tesseract/Output/OUT_Leg_001_DA00_cat_002.pdf
# Completed 43.7 KiB/43.7 KiB (419.4 KiB/s) with 1 file(s) remaining#015upload: ./OUT_Leg_001_DA00_cat_002.pdf_hocr.tar.gz to s3://348831852500-sagemaker-us-east-1/Tesseract/Output/OUT_Leg_001_DA00_cat_002.pdf_hocr.tar.gz
# ################################ PROCESSING COMPLETE ##########################
# Returning
# {'predictions': {}}
# 169.254.255.130 - - [25/Jan/2020:10:25:34 +0000] "POST /invocations HTTP/1.1" 200 19 "-" "Go-http-client/1.1"
# Completed 43.7 KiB/43.7 KiB (419.4 KiB/s) with 1 file(s) remaining#015upload: ./OUT_Leg_001_DA00_cat_002.pdf_hocr.tar.gz to s3://348831852500-sagemaker-us-east-1/Tesseract/Output/OUT_Leg_001_DA00_cat_002.pdf_hocr.tar.gz
# ################################ PROCESSING COMPLETE ##########################
# Returning
# {'predictions': {}}
# 169.254.255.130 - - [25/Jan/2020:10:25:34 +0000] "POST /invocations HTTP/1.1" 200 19 "-" "Go-http-client/1.1"
# Request
# text/csv
# Data
# Start Processing
# Input Bucket: 348831852500-sagemaker-us-east-1
# Request
# text/csv
# Data
# Start Processing
# Input Bucket: 348831852500-sagemaker-us-east-1
# Input Path: Tesseract/Input
# Input File Name: Leg_027_IR01_cat_025.pdf
# Output Bucket:
# Output Path: Tesseract/Output
# Output File Name: OUT_Leg_027_IR01_cat_025.pdf
# ############################### DOWNLOAD INPUT FILE ###########################
# Input Path: Tesseract/Input
# Input File Name: Leg_027_IR01_cat_025.pdf
# Output Bucket:
# Output Path: Tesseract/Output
# Output File Name: OUT_Leg_027_IR01_cat_025.pdf
# ############################### DOWNLOAD INPUT FILE ###########################
# Completed 256.0 KiB/1.2 MiB (3.1 MiB/s) with 1 file(s) remaining#015Completed 512.0 KiB/1.2 MiB (6.0 MiB/s) with 1 file(s) remaining#015Completed 768.0 KiB/1.2 MiB (8.8 MiB/s) with 1 file(s) remaining#015Completed 1.0 MiB/1.2 MiB (11.5 MiB/s) with 1 file(s) remaining #015Completed 1.2 MiB/1.2 MiB (13.3 MiB/s) with 1 file(s) remaining #015download: s3://348831852500-sagemaker-us-east-1/Tesseract/Input/Leg_027_IR01_cat_025.pdf to ./Leg_027_IR01_cat_025.pdf
# ############################### TESSERACT EXECUTION ###########################
# pdfsandwich version 0.1.7
# Input file: "Leg_027_IR01_cat_025.pdf"
# Output file: "Leg_027_IR01_cat_025_ocr.pdf"
# Number of pages in inputfile: 6
# More threads than pages. Using 6 threads instead.
#
# Parallel processing with 6 threads started.
# Processing page order may differ from original page order.
#
# Processing page 5.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[4]"
# Processing page 1.
# Processing page 6.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[5]"
# Processing page Processing page identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[0]" Processing page 2.
# 3.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[2]"
#
# 4identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[1]"
# .
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[3]"
# Completed 256.0 KiB/1.2 MiB (3.1 MiB/s) with 1 file(s) remaining#015Completed 512.0 KiB/1.2 MiB (6.0 MiB/s) with 1 file(s) remaining#015Completed 768.0 KiB/1.2 MiB (8.8 MiB/s) with 1 file(s) remaining#015Completed 1.0 MiB/1.2 MiB (11.5 MiB/s) with 1 file(s) remaining #015Completed 1.2 MiB/1.2 MiB (13.3 MiB/s) with 1 file(s) remaining #015download: s3://348831852500-sagemaker-us-east-1/Tesseract/Input/Leg_027_IR01_cat_025.pdf to ./Leg_027_IR01_cat_025.pdf
# ############################### TESSERACT EXECUTION ###########################
# pdfsandwich version 0.1.7
# Input file: "Leg_027_IR01_cat_025.pdf"
# Output file: "Leg_027_IR01_cat_025_ocr.pdf"
# Number of pages in inputfile: 6
# More threads than pages. Using 6 threads instead.
#
# Parallel processing with 6 threads started.
# Processing page order may differ from original page order.
#
# Processing page 5.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[4]"
# Processing page 1.
# Processing page 6.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[5]"
# Processing page Processing page identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[0]" Processing page 2.
# 3.
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[2]"
#
# 4identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[1]"
# .
# identify -format "%w\n%h\n"  "/tmp/pdfsandwich_tmp6a4e91/pdfsandwich_inputfile79c8fc.pdf[3]"
